# %%
pip install nest-asyncio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import twint

# %%
#error

c = twint.Config()
c.To = "IndiHome"
c.Search = "error"
c.Limit = 2100
c.Since = '2020-01-01'
c.Until = '2020-12-31'
c.Store_csv = True
c.Output = "IndiHome_reply_2020_error.csv"

# %%
twint.run.Search(c)
# Out:
# 1344282440349585413 2020-12-30 21:01:23 +0700 <GVSaraswati> @IndiHome Mau maraton film tapi indihome lagi kumat, error nggak kelar² padahal udah di pandu by phone ama teknisinya 🙄
# 1344258076325548040 2020-12-30 19:24:35 +0700 <Cahmul1> @IndiHome KUALITAS DITAMBAHIN WOYY, CS SAMA TEKNISI LAMBAT, INTERNET ERROR MULU. SETAHUN KAGAK BISA APA KAGAK ERROR. MAKANNYA SAHAM TURUN. JANGAN TIDOERR AJEEE
# 1344241395385602049 2020-12-30 18:18:18 +0700 <Sofian96005771> @IndiHome error
# 1344138164382756865 2020-12-30 11:28:05 +0700 <gyianfhong> @IndiHome ini error kah? Kok indihome saya ga konek yaa?
# 1344102889644384256 2020-12-30 09:07:55 +0700 <RizkyP20538960> @IndiHome min, beberapa hari lalu internetnya udah bener. ko sekarang error lagi ya, lampunnya hijau semua tapi (hanya lampu di indikator 'internet' yang mati. tolong segera di cek min
# ...

# %%
#benerin

c = twint.Config()
c.To = "IndiHome"
c.Search = "benerin"
c.Limit = 2100
c.Since = '2020-01-01'
c.Until = '2020-12-31'
c.Store_csv = True
c.Output = "IndiHome_reply_2020_benerin.csv"

# %%
twint.run.Search(c)
# Out:
# 1344261728935182337 2020-12-30 19:39:06 +0700 <diaah_ap> @IndiHome akak, wifiku lampunya merah terus dari tadi gak bisa buat internet 😫 benerin dong kak, aku mau nonton yutub 😫
# 1344196353858027521 2020-12-30 15:19:19 +0700 <dameddaa> @IndiHome beneran ini hangus semuanya? kagak ada merchant yang menarik lg
# 1344154749990400000 2020-12-30 12:34:00 +0700 <nadiabasandid> @IndiHome Lagian kalo emang kurang jelas nama jalannya kan bisa hubungin saya,buat apa diminta nomer tlp customer kalo nggak dihubungin. Kalo emang udah beneran mau ngecek ke lokasi, pasti ketemu. Itu di jalan besar bukan yg terpencil masuk2 gang.Nama perumahannya bloknya semua udah jelas
# 1344068016045051904 2020-12-30 06:49:21 +0700 <infoHendri> @IndiHome Gw gak butuh ip static.. gw butuh 1 local ip gw static, lu tau gak IP yg mulainya  https://t.co/L5KdxQBHtK nah itu yg butuh 1 static bkn router ip publicnya static bambanh @IndiHome benerin internet nya du dah
# ...

# %%
#gangguan

c = twint.Config()
c.To = "IndiHome"
c.Search = "gangguan"
c.Limit = 2100
c.Since = '2020-01-01'
c.Until = '2020-12-31'
c.Store_csv = True
c.Output = "IndiHome_reply_2020_gangguan.csv"

# %%
twint.run.Search(c)
# Out:
# 1344425607178854400 2020-12-31 06:30:17 +0700 <Dimas_YD> @IndiHome @TelkomCare wifi gangguan njirrrr
# 1344415711578320897 2020-12-31 05:50:58 +0700 <daitaro69> @IndiHome lagi gangguan ya @TelkomCare kok ngga bs buka TV  https://t.co/EEVWChOb3s
# 1344347598434361344 2020-12-31 01:20:18 +0700 <AtapMiring> @IndiHome Ada gangguan atau gimana?
# 1344343449688948736 2020-12-31 01:03:49 +0700 <AtapMiring> @IndiHome ada gangguan kah ?
# 1344320091131764736 2020-12-30 23:31:00 +0700 <kekentangan2> @IndiHome aku mau main ml tanpa gangguan . iso ora ?  https://t.co/Ws1Tg19AzB
# 1344277759242080263 2020-12-30 20:42:47 +0700 <Deadactived> @IndiHome min ini indihome daerah Rawamangun apakah memang sedang gangguan? Dari siang loh ini router nya merah terus udah coba restart router beberapa kali ga bener"  https://t.co/VjyXDq2mfO
# ...
